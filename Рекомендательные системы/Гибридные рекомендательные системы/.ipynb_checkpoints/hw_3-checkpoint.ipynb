# %% [markdown]
# ## Гибридные рекомендательные системы
#
# - Датасет ml-latest
# - Вспомнить подходы, которые мы разбирали
# - Выбрать понравившийся подход к гибридным системам
# - Написать свою

# %%
from surprise import SVD, SVDpp
from surprise import Dataset
from surprise import accuracy
from surprise import Reader
#from surprise.model_selection import train_test_split

import matplotlib.pyplot as plt

from tqdm import tqdm_notebook

from sklearn.feature_extraction.text import TfidfTransformer, CountVectorizer
from sklearn.neighbors import NearestNeighbors

import pandas as pd
import numpy as np
import xgboost

# %matplotlib inline
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestClassifier

from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split

from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVR
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
tags = pd.read_csv('tags.csv')

# %%
movies.head(2)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy
#
#                               genres_formatted
# 0  adventure animation children comedy fantasy
# 1                   adventure children fantasy

# %%
ratings.head(2)
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247

# %%
movies_with_ratings = movies.join(ratings.set_index('movieId'), on='movieId').reset_index(drop=True)
movies_with_ratings.dropna(inplace=True)

# %%
dataset = pd.DataFrame({
    'uid': movies_with_ratings.userId,
    'iid': movies_with_ratings.title,
    'rating': movies_with_ratings.rating
})

# %% [markdown]
# ## Попробуем стекинг что-ли. Обучим кучу моделек разных

# %% [markdown]
# ### 1) Сформируем оценки на основе средних

# %%
raitis_aggr= ratings.groupby(['movieId'])[['rating']].count()
raitis_aggr.columns=['count_']
raitis_aggr['mean_']= ratings.groupby(['movieId'])[['rating']].mean()
raitis_aggr['median_']= ratings.groupby(['movieId'])[['rating']].median()
raitis_aggr['var_']= ratings.groupby(['movieId'])[['rating']].var()

# %%
raitis_aggr.head()
# Out:
#          count_     mean_  median_      var_
# movieId
# 1           215  3.920930      4.0  0.696990
# 2           110  3.431818      3.5  0.777419
# 3            52  3.259615      3.0  1.112651
# 4             7  2.357143      3.0  0.726190
# 5            49  3.071429      3.0  0.822917

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
x = pd.merge(ratings[['userId','movieId','rating']], raitis_aggr, on='movieId', how='left')
y=x.rating
x=x.drop(['rating'], axis=1)
x=x.drop(['userId'], axis=1)
x=x.drop(['movieId'], axis=1)
x.var_  = x.var_.fillna(0)

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.3,random_state=42)

# %%
from xgboost import XGBRegressor

# %%
model = xgboost.XGBRegressor()
model.fit(X_train, y_train)
# Out:
# /home/gavril/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#        nthread=None, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=1)

# %%
predictions_from_mean = model.predict(X_test)

print('root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, predictions_from_mean)))
# Out:
# root_mean_squared_error =  0.8812635936575153

# %%
# Попробуем улчшить релузьтаты гридом
params = {'min_child_weight':[4,5], 'gamma':[i/10.0 for i in range(3,6)],  'subsample':[i/10.0 for i in range(6,11)],
'colsample_bytree':[i/10.0 for i in range(6,11)], 'max_depth': [2,3,4]}

# Initialize XGB and GridSearch
xgb = XGBRegressor(nthread=-1) 

grid_means = GridSearchCV(xgb, params)
grid_means.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/gavril/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/gavril/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/gavril/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# ...

# %%
grid_means.best_params_
# Out:
# {'colsample_bytree': 1.0,
#  'gamma': 0.5,
#  'max_depth': 2,
#  'min_child_weight': 5,
#  'subsample': 1.0}

# %%
predictions_mean =grid_means.best_estimator_.predict(X_test)

# %%
# Ну самую малость лучше стало
np.sqrt(mean_squared_error(predictions_mean, y_test))
# Out:
# 0.8793501185677871

# %% [markdown]
# #### Запишем предикты для мета модели

# %%
X_means=grid_means.best_estimator_.predict(x)

# %%
X_means.shape
# Out:
# (100836,)

# %%
x.shape
# Out:
# (100836, 4)

# %% [markdown]
# ### 2) Сформируем оценки на основе жанров

# %%
def change_string(s):
    return ' '.join(s.lower().replace(' ', '').replace('-', '').split('|'))

# %%
# Нормализуем жанры
movies['genres_formatted'] = movies.genres.apply(change_string)

# %%
x = ratings[['userId','movieId','rating']]

# %%
movies.head(2)
# Out:
#    movieId             title                                       genres  \
# 0        1  Toy Story (1995)  Adventure|Animation|Children|Comedy|Fantasy
# 1        2    Jumanji (1995)                   Adventure|Children|Fantasy
#
#                               genres_formatted
# 0  adventure animation children comedy fantasy
# 1                   adventure children fantasy

# %%
x = pd.merge(x, movies[['movieId','genres_formatted']], on='movieId', how='left')

# %%
x.shape
# Out:
# (100836, 4)

# %%
x.head()
# Out:
#    userId  movieId  rating                             genres_formatted
# 0       1        1     4.0  adventure animation children comedy fantasy
# 1       1        3     4.0                               comedy romance
# 2       1        6     4.0                        action crime thriller
# 3       1       47     5.0                             mystery thriller
# 4       1       50     5.0                       crime mystery thriller

# %%
x.isnull().any()
# Out:
# userId              False
# movieId             False
# rating              False
# genres_formatted    False
# dtype: bool

# %% [raw]
# y=x.rating

# %%
x=x.drop(['rating'], axis=1)
x=x.drop(['userId'], axis=1)
x=x.drop(['movieId'], axis=1)

# %%
cv_genres_ = CountVectorizer()
tf_genres = TfidfTransformer()

# %%
cv_genres = cv_genres_.fit_transform(x.genres_formatted)

# %%
tfidf_genres= tf_genres.fit_transform(cv_genres)

# %%
tfidf_genres
# Out:
# <100836x20 sparse matrix of type '<class 'numpy.float64'>'
# 	with 274480 stored elements in Compressed Sparse Row format>

# %%
X_train, X_test, y_train, y_test = train_test_split(tfidf_genres, y, test_size=0.3,random_state=42)

# %%
params = {'min_child_weight':[4,5], 'gamma':[i/10.0 for i in range(3,6)],  'subsample':[i/10.0 for i in range(6,11)],
'colsample_bytree':[i/10.0 for i in range(6,11)], 'max_depth': [2,3,4]}

# Initialize XGB and GridSearch
xgb = XGBRegressor(nthread=-1) 

grid_genres = GridSearchCV(xgb, params)
grid_genres.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/gavril/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/gavril/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# /home/gavril/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# ...

# %%
# сохраним предсказания для стекинга
predictions_genres =grid_genres.best_estimator_.predict(X_test)

# %%
# Ну самую малость лучше стало
np.sqrt(mean_squared_error(predictions_genres, y_test))
# Out:
# 1.0079105264879307

# %% [markdown]
# #### Запишем предикты для мета модели

# %%
X_genres=grid_genres.best_estimator_.predict(tfidf_genres)

# %%
predictions_mean.shape
# Out:
# (30251,)

# %%
predictions_genres.shape
# Out:
# (30251,)

# %% [markdown]
# ### 3) Сформируем оценки на основе тегов

# %%
# слепим теги каждого юзера,  если они относятся к одному фильму
tags['tag_new'] = tags[['userId','movieId','tag']].groupby(['userId','movieId'])['tag'].transform(lambda x: ' '.join(x))
tags=tags[['userId','movieId','tag_new']].drop_duplicates()

# %%
import pymorphy2
from nltk.tokenize import word_tokenize
import nltk
#nltk.download('punkt')
from tqdm import tqdm

# %%
class MorphProvider:
    def __init__(self):
        self.cache = {}
        self.morph = pymorphy2.MorphAnalyzer()
    
    def __call__(self, w):
        w = w.lower()
        cached = self.cache.get(w)
        if cached:
            return cached
        try:
            morphed = self.morph.parse(w)[0].normal_form
            self.cache[w] = morphed
            return morphed
        except:
            return None
    
    def morph_string(self, s):
        words = word_tokenize(s)
        return " ".join([self.__call__(w) for w in words])

# %%
morph = MorphProvider()

# %%
tags["tag_normalized"] = [morph.morph_string(t) for t in tqdm(tags.tag_new)]
# Out:
# 100%|██████████| 1775/1775 [00:00<00:00, 7751.75it/s]

# %%
tags=tags.drop(['tag_new'], axis=1)

# %%
x = ratings[['userId','movieId','rating']]

# %%
x = pd.merge(x, tags[['movieId','userId','tag_normalized']], on=['userId','movieId'], how='left')

# %%
x.tag_normalized = x.tag_normalized.fillna('')

# %%
y= x.rating

# %%
x=x.drop(['rating'], axis=1)
x=x.drop(['userId'], axis=1)
x=x.drop(['movieId'], axis=1)

# %%
cv_tags = CountVectorizer()
tf_tags = TfidfTransformer()
cv_tags = cv_tags.fit_transform(x.tag_normalized)
tfidf_tags= tf_tags.fit_transform(cv_genres)

# %%
X_train, X_test, y_train, y_test = train_test_split(tfidf_tags, y, test_size=0.3,random_state=42)

# %%
params = {'min_child_weight':[4,5], 'gamma':[i/10.0 for i in range(3,6)],  'subsample':[i/10.0 for i in range(6,11)],
'colsample_bytree':[i/10.0 for i in range(6,11)], 'max_depth': [2,3,4]}

# Initialize XGB and GridSearch
xgb = XGBRegressor(nthread=-1) 

grid_tags = GridSearchCV(xgb, params,n_jobs=-1)
grid_tags.fit(X_train, y_train)
# Out:
# /usr/local/lib/python3.6/dist-packages/sklearn/model_selection/_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# /home/gavril/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=3,
#        min_child_weight=1, missing=None, n_estimators=100, n_jobs=1,
#        nthread=-1, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=1),
# ...

# %%
# сохраним предсказания для стекинга
predictions_tags =grid_tags.best_estimator_.predict(X_test)

# %%
# Ну самую малость лучше стало
np.sqrt(mean_squared_error(predictions_tags, y_test))
# Out:
# 1.0079105264879307

# %% [markdown]
# #### Запишем предикты для мета модели

# %%
X_tags=grid_tags.best_estimator_.predict(tfidf_tags)

# %%
X_tags.shape
# Out:
# (100836,)

# %% [markdown]
# ### 3) Сформируем какие-нибудь коллобративные оценки оценки

# %%
movies_with_ratings = movies.join(ratings.set_index('movieId'), on='movieId').reset_index(drop=True)
movies_with_ratings.dropna(inplace=True)

# %%
dataset = pd.DataFrame({
    'uid': movies_with_ratings.userId,
    'iid': movies_with_ratings.title,
    'rating': movies_with_ratings.rating
})

# %%
x = pd.merge(ratings[['userId','movieId','rating']], raitis_aggr, on='movieId', how='left')
y=x.rating
x=x.drop(['rating'], axis=1)
x=x.drop(['userId'], axis=1)
x=x.drop(['movieId'], axis=1)
x.var_  = x.var_.fillna(0)

# %%
from surprise.model_selection import train_test_split

# %%
import surprise
from surprise import KNNWithMeans, KNNBasic,KNNWithZScore,KNNBaseline,CoClustering,BaselineOnly,SlopeOne,NMF,SVDpp,SVD
from surprise import Dataset
from surprise import accuracy
from surprise import Reader

# %%
reader = Reader(rating_scale=(ratings.rating.min(), ratings.rating.max()))
data = Dataset.load_from_df(dataset, reader)

# %%
trainset, testset = surprise.model_selection.train_test_split(data, test_size=.3, random_state=42)

# %%
algo_KNNWithMeans_user_bases_true = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'min_support': 1, 'user_based': True})
algo_KNNWithMeans_user_bases_true.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
test_pred =algo_KNNWithMeans_user_bases_true.test(testset)

# %%
accuracy.rmse(test_pred, verbose=True)
# Out:
# RMSE: 0.9042
# 0.9042209720712455

# %%
X_KNNWithMeans_user_bases_true=np.array([])

# %%
X_KNNWithMeans_user_bases_true.shape
# Out:
# (0,)

# %%
 for row in dataset.index:
        #print(dataset.loc[row])
        X_KNNWithMeans_user_bases_true=np.append(X_KNNWithMeans_user_bases_true,algo_KNNWithMeans_user_bases_true.predict(uid=dataset.loc[row]['uid'], iid=dataset.loc[row]['iid']).est)
        #print(X_KNNWithMeans_user_bases_true)

# %%
X_KNNWithMeans_user_bases_true.shape
# Out:
# (100836,)

# %%
algo_KNNWithMeans_user_bases_false = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'min_support': 1, 'user_based': False})
algo_KNNWithMeans_user_bases_false.fit(trainset)
test_pred =algo_KNNWithMeans_user_bases_false.test(testset)
accuracy.rmse(test_pred, verbose=True)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.
# RMSE: 0.8875
# 0.8875246649492732

# %% [markdown]
# #### Запишем предикты для мета модели

# %%
X_KNNWithMeans_user_bases_false=np.array([])
for row in dataset.index:
        #print(dataset.loc[row])
        X_KNNWithMeans_user_bases_false=np.append(X_KNNWithMeans_user_bases_false,algo_KNNWithMeans_user_bases_false.predict(uid=dataset.loc[row]['uid'], iid=dataset.loc[row]['iid']).est)
        #print(X_KNNWithMeans_user_bases_true)

# %%
X_KNNWithMeans_user_bases_false.shape
# Out:
# (100836,)

# %% [markdown]
# ### 4) Сформируем оценки на основе SVD

# %%
algo_SVDpp= SVDpp()
algo_SVDpp.fit(trainset)

# %%
test_pred =algo_SVDpp.test(testset)
accuracy.rmse(test_pred, verbose=True)
# Out:
# RMSE: 0.8640
# 0.863955050787103

# %% [markdown]
# #### Запишем предикты для мета модели

# %%
X_SVDpp=np.array([])
for row in dataset.index:
        
        X_SVDpp=np.append(X_SVDpp,algo_SVDpp.predict(uid=dataset.loc[row]['uid'], iid=dataset.loc[row]['iid']).est)

# %%
X_SVDpp.shape
# Out:
# (100836,)

# %% [markdown]
# ### Слепим все в один датасет

# %%
X_meta=pd.DataFrame(np.column_stack((X_genres,X_KNNWithMeans_user_bases_false,X_means,X_KNNWithMeans_user_bases_true,X_SVDpp,X_tags)) , columns=['X_genres','X_KNNWithMeans_user_bases_false','X_means','X_KNNWithMeans_user_bases_true','X_SVDpp','X_tags'])

# %%
X_meta.head()
# Out:
#    X_genres  X_KNNWithMeans_user_bases_false   X_means  \
# 0  3.725041                         4.369389  3.902271
# 1  3.298112                         4.018450  3.256071
# 2  3.498157                         4.104486  3.952530
# 3  3.834330                         2.889905  3.962551
# 4  3.927869                         4.267658  4.211724
#
#    X_KNNWithMeans_user_bases_true   X_SVDpp    X_tags
# 0                        4.317756  4.409919  3.725041
# 1                        4.132903  3.819933  3.298112
# 2                        3.699561  3.688820  3.498157
# 3                        3.134089  3.464480  3.834330
# 4                        4.554116  4.112793  3.927869

# %%
X_train, X_test, y_train, y_test = train_test_split(X_meta, y, test_size=0.3,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ### Попробуем подобрать лучшую моедль

# %%
lr_params={'fit_intercept':[True,False],
           'normalize':[True,False]
            }
grid_lr = GridSearchCV(cv=3, param_grid=lr_params, estimator=LinearRegression(),n_jobs=-1,scoring='neg_mean_squared_error')
grid_lr.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=3, error_score='raise-deprecating',
#        estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'fit_intercept': [True, False], 'normalize': [True, False]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='neg_mean_squared_error', verbose=0)

# %%
print(grid_lr.best_params_)
print(grid_lr.best_score_)
print(grid_lr.best_estimator_)
print('root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, grid_lr.best_estimator_.predict(X_test))))
# Out:
# {'fit_intercept': True, 'normalize': True}
# -0.7660317979790772
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True)
# root_mean_squared_error =  0.8793424185112372

# %% [markdown]
# ### Попробуем регуляризировать

# %%
# %%time
from sklearn.linear_model import Ridge

ridge_params = {'fit_intercept':[True,False],
  'alpha': [100,25,10,4,2,1.0,0.8,0.5,0.3,0.2,0.1,0.05,0.02,0.01],
'solver' : ['auto', 'svd', 'cholesky', 'lsqr', 'sparse_cg', 'sag', 'saga']

}
grid_ridge = GridSearchCV(cv=3, param_grid=ridge_params, estimator=Ridge(),n_jobs=-1)
grid_ridge.fit(X_train,y_train)
print(grid_ridge.best_params_)
print(grid_ridge.best_score_)
print(grid_ridge.best_estimator_)
print('root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, grid_ridge.best_estimator_.predict(X_test))))
# Out:
# {'alpha': 0.3, 'fit_intercept': False, 'solver': 'sag'}
# 0.29396018984641764
# Ridge(alpha=0.3, copy_X=True, fit_intercept=False, max_iter=None,
#    normalize=False, random_state=None, solver='sag', tol=0.001)
# root_mean_squared_error =  0.8793496571634117
# CPU times: user 3.18 s, sys: 681 ms, total: 3.86 s
# Wall time: 24.4 s

# %%
# %%time
from sklearn import linear_model

lasso_params = {'fit_intercept':[True,False],
  'alpha': [100,25,10,4,2,1.0,0.8,0.5,0.3,0.2,0.1,0.05,0.02,0.01],
'warm_start'  :[True,False]

}
grid_lasso = GridSearchCV(cv=3, param_grid=lasso_params, estimator=Lasso(),n_jobs=-1)
grid_lasso.fit(X_train,y_train)
print(grid_lasso.best_params_)
print(grid_lasso.best_score_)
print(grid_lasso.best_estimator_)
print('root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, grid_lasso.best_estimator_.predict(X_test))))
# Out:
# {'alpha': 0.01, 'fit_intercept': False, 'warm_start': True}
# 0.2940268890817326
# Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=True)
# root_mean_squared_error =  0.8793387047782515
# CPU times: user 1.33 s, sys: 404 ms, total: 1.74 s
# Wall time: 8.29 s

# %%
# %%time

knn_params = {
    'n_neighbors':list(range(1, 30))
   ,'weights': ['uniform', 'distance']
   ,'algorithm' : ['auto', 'ball_tree', 'kd_tree', 'brute']
   ,'leaf_size':list(range(5, 30))
}

grid_knn = RandomizedSearchCV(KNeighborsRegressor(), knn_params,  scoring='neg_mean_squared_error',
                       cv=3,n_jobs=-1)
grid_knn.fit(X_train, y_train)
print(grid_knn.best_params_)
print(grid_knn.best_score_)
print(grid_knn.best_estimator_)
print('root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, grid_knn.best_estimator_.predict(X_test))))
# Out:
# {'weights': 'distance', 'n_neighbors': 24, 'leaf_size': 20, 'algorithm': 'auto'}
# -0.8004306350878968
# KNeighborsRegressor(algorithm='auto', leaf_size=20, metric='minkowski',
#           metric_params=None, n_jobs=None, n_neighbors=24, p=2,
#           weights='distance')
# root_mean_squared_error =  0.9004307609218763
# CPU times: user 1.27 s, sys: 84.5 ms, total: 1.35 s
# Wall time: 3min 40s

# %%
# %%time
dt_params = {
    'max_depth':[None,1,2,5,10,25,50],
     'min_samples_split':[2,5,8,10,25,50],
    
    'min_weight_fraction_leaf': [0, 0.01, 0.1, 0.15, 0.25, 0.5] ,
    'min_samples_leaf':list(range(1, 10)),
     'criterion':  ['mse', 'friedman_mse', 'mae'],
    'max_features':list(range(1, 6)) 
}
#model_forest = RandomForestRegressor(
    

grid_dt =  RandomizedSearchCV(DecisionTreeRegressor(),dt_params,  scoring='neg_mean_squared_error',
                       cv=3,n_jobs=-1)
grid_dt.fit(X_train, y_train)
print(grid_dt.best_params_)
print(grid_dt.best_score_)
print(grid_dt.best_estimator_)
print('root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, grid_dt.best_estimator_.predict(X_test))))
# Out:
# {'min_weight_fraction_leaf': 0.01, 'min_samples_split': 10, 'min_samples_leaf': 6, 'max_features': 3, 'max_depth': 25, 'criterion': 'mae'}
# -0.820485938938868
# DecisionTreeRegressor(criterion='mae', max_depth=25, max_features=3,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=6,
#            min_samples_split=10, min_weight_fraction_leaf=0.01,
#            presort=False, random_state=None, splitter='best')
# root_mean_squared_error =  0.915137392449681
# CPU times: user 1min 17s, sys: 40 ms, total: 1min 17s
# Wall time: 2min 9s

# %%
# %%time
rf_params = {
    'n_estimators': [1,10,20,30,40,50,60,80,90],
    
    'max_depth':[None,1,2,5,10,25,50],
    
    'min_samples_leaf':list(range(1, 10)),
   
    'max_features':list(range(1, 6)) ,
     'criterion':  ['mse', 'friedman_mse', 'mae']
}

    

grid_rf =  RandomizedSearchCV(RandomForestRegressor(),rf_params,scoring='neg_mean_squared_error',
                       cv=3,n_jobs=-1)
grid_rf.fit(X_train, y_train)
print(grid_rf.best_params_)
print(grid_rf.best_score_)
print(grid_rf.best_estimator_)
print('root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, grid_rf.best_estimator_.predict(X_test))))
# Out:
# {'n_estimators': 40, 'min_samples_leaf': 6, 'max_features': 1, 'max_depth': 50, 'criterion': 'mae'}
# -0.7987042644727989
# RandomForestRegressor(bootstrap=True, criterion='mae', max_depth=50,
#            max_features=1, max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=6,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            n_estimators=40, n_jobs=None, oob_score=False,
#            random_state=None, verbose=0, warm_start=False)
# root_mean_squared_error =  0.8987092920248273
# CPU times: user 23min 23s, sys: 558 ms, total: 23min 23s
# Wall time: 49min 33s

# %%
# %%time
from sklearn.ensemble.gradient_boosting import GradientBoostingRegressor
gb_params = {
          'n_estimators': [1,10,20,30,40,50,60,80,90],
          'max_features': list(range(1, 6)),
             'max_depth':[None,1,2,5,10,25,50],
            'learning_rate': [0.1,0.3,0.5,0.7],
               #'min_samples_split':[2,5,8,10,25,50],
            'min_samples_leaf':list(range(1, 10)),
}

    

grid_gb =  RandomizedSearchCV(GradientBoostingRegressor(),gb_params,scoring='neg_mean_squared_error',
                       cv=3,n_jobs=-1)
grid_gb.fit(X_train, y_train)
print(grid_gb.best_params_)
print(grid_gb.best_score_)
print(grid_gb.best_estimator_)
print('root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, grid_gb.best_estimator_.predict(X_test))))
# Out:
# {'n_estimators': 10, 'min_samples_leaf': 8, 'max_features': 5, 'max_depth': 10, 'learning_rate': 0.3}
# -0.7953173169621777
# GradientBoostingRegressor(alpha=0.9, criterion='friedman_mse', init=None,
#              learning_rate=0.3, loss='ls', max_depth=10, max_features=5,
#              max_leaf_nodes=None, min_impurity_decrease=0.0,
#              min_impurity_split=None, min_samples_leaf=8,
#              min_samples_split=2, min_weight_fraction_leaf=0.0,
#              n_estimators=10, n_iter_no_change=None, presort='auto',
#              random_state=None, subsample=1.0, tol=0.0001,
#              validation_fraction=0.1, verbose=0, warm_start=False)
# root_mean_squared_error =  0.8924685000578382
# CPU times: user 2.09 s, sys: 352 ms, total: 2.44 s
# Wall time: 2min 13s

# %%
# %%time

xgb_params =  {'min_child_weight':[4,5], 'gamma':[i/10.0 for i in range(3,6)],  'subsample':[i/10.0 for i in range(6,11)],
'colsample_bytree':[i/10.0 for i in range(6,11)], 'max_depth': [2,3,4]}

    

grid_xgb =  RandomizedSearchCV(XGBRegressor(nthread=-1) ,xgb_params,scoring='neg_mean_squared_error',
                       cv=3,n_jobs=-1)
grid_xgb.fit(X_train, y_train)
print(grid_xgb.best_params_)
print(grid_xgb.best_score_)
print(grid_xgb.best_estimator_)
print('root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, grid_xgb.best_estimator_.predict(X_test))))
# Out:
# /home/gavril/.local/lib/python3.6/site-packages/xgboost/core.py:587: FutureWarning: Series.base is deprecated and will be removed in a future version
#   if getattr(data, 'base', None) is not None and \
# {'subsample': 0.9, 'min_child_weight': 4, 'max_depth': 2, 'gamma': 0.3, 'colsample_bytree': 0.8}
# -0.7693904069678675
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=0.8, gamma=0.3, importance_type='gain',
#        learning_rate=0.1, max_delta_step=0, max_depth=2,
#        min_child_weight=4, missing=None, n_estimators=100, n_jobs=1,
#        nthread=-1, objective='reg:linear', random_state=0, reg_alpha=0,
#        reg_lambda=1, scale_pos_weight=1, seed=None, silent=True,
#        subsample=0.9)
# root_mean_squared_error =  0.8811777872809955
# CPU times: user 1.56 s, sys: 32.1 ms, total: 1.6 s
# Wall time: 7.94 s

# %%
params = {'min_child_weight':[4,5], 'gamma':[i/10.0 for i in range(3,6)],  'subsample':[i/10.0 for i in range(6,11)],
'colsample_bytree':[i/10.0 for i in range(6,11)], 'max_depth': [2,3,4]}

# Initialize XGB and GridSearch
xgb = XGBRegressor(nthread=-1) 

grid_means = GridSearchCV(xgb, params)
grid_means.fit(X_train, y_train)

# %%
models=['xgb','gb','dt','rf','knn','lr','lasso','ridge']
for model_ in models:
    print(model_,'---','root_mean_squared_error = ', np.sqrt(mean_squared_error(y_test, eval('grid_'+model_+'.best_estimator_').predict(X_test))))
# Out:
# xgb --- root_mean_squared_error =  0.8811777872809955
# gb --- root_mean_squared_error =  0.8924685000578382
# dt --- root_mean_squared_error =  0.915137392449681
# rf --- root_mean_squared_error =  0.8987092920248273
# knn --- root_mean_squared_error =  0.9004307609218763
# lr --- root_mean_squared_error =  0.8793424185112372
# lasso --- root_mean_squared_error =  0.8793387047782515
# ridge --- root_mean_squared_error =  0.8793496571634117

# %%
grid_lasso.best_estimator_.get_params
# Out:
# <bound method BaseEstimator.get_params of Lasso(alpha=0.01, copy_X=True, fit_intercept=False, max_iter=1000,
#    normalize=False, positive=False, precompute=False, random_state=None,
#    selection='cyclic', tol=0.0001, warm_start=True)>

# %%
grid_lasso.best_estimator_.coef_
# Out:
# array([0.        , 0.        , 0.99940709, 0.        , 0.        ,
#        0.        ])

# %%
imp = pd.Series(grid_lasso.best_estimator_.coef_)
imp=imp.sort_values(ascending=False)

# %% [markdown]
# ### Любоптыно -Lasso  обнулил все кроме жанров

# %%
plt.rcParams["figure.figsize"] = (20,20)
n_features =len(imp[:30])

plt.barh(range(n_features), imp[:30], align='center')
plt.yticks(np.arange(n_features), X_train.columns)
plt.xlabel("Важность признака")
plt.ylabel("Признак")
# Out:
# Text(0, 0.5, 'Признак')
